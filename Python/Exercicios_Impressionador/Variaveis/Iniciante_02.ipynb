# %% [markdown]
# # Lista de Estrutura Sequencial

# %% [markdown]
# #### 1. Faça um Programa que mostre a mensagem (print) "Alo mundo" na tela.

# %%
print('Ola Mundo')
# Out:
# Ola Mundo

# %% [markdown]
# #### 2. Faça um Programa que peça um número (input) e então mostre a mensagem: "O número informado foi [número]."

# %%
num = input('Digite um número: ')
print('O número digitado foi {}'.format(num))
# Out:
# O número digitado foi 5

# %% [markdown]
# #### 3. Faça um Programa que peça dois números e imprima a soma.

# %%
num = input('Digite um número: ')
num2 = input('Digite outro número: ')

try: 
    num = int(num)
    num2 = int(num2)
    soma = num + num2
    print(f'A soma dos números digitados foi: {soma}')
except:
    print('Valores digitados são inválidos')
# Out:
# A soma dos números digitados foi: 9

# %% [markdown]
# #### 4. Faça um Programa que peça as 4 notas bimestrais de um aluno e mostre a média de todas as notas.

# %%
contador = 1
nota_total = 0

for x in range(4):
    try:
        num = int(input(f'Digite a {contador}° nota do aluno'))
        nota_total += num
        contador += 1
    except:
        print('Valor digitado é inválido\nPor favor, reinicie o processo')
        break

media = nota_total / 4

print(f'Nota média: {media}')
# Out:
# Nota média: 6.0

# %% [markdown]
# #### 5. Faça um Programa que converta metros para centímetros. Você pode pedir o comprimento em metros para o usuário (input).

# %%
metros = int(input('Digite um valor me metros: '))
cm = metros * 1000

print(f"{metros}m tem {cm}cm")
# Out:
# 5m tem 5000cm

# %% [markdown]
# #### 6. Faça um Programa que calcule a área de uma sala de um apartamento. Para isso, o seu programa precisa pedir a largura da sala, o comprimento da sala e imprimir a área em m² da sala.

# %%
largura = int(input('Digite a largura: '))
comprimento = int(input('Digite o comprimento: '))

metros_quadrados = largura * comprimento

print(f'Sua peça tem {metros_quadrados}M²')
# Out:
# Sua peça tem 21M²

# %% [markdown]
# #### 7. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.

# %%
valor_hora = float(input('Valor da hora: '))
horas_trabalhadas = int(input('Horas trabalhadas: '))

salario = valor_hora * horas_trabalhadas

print(f'Salário: R$ {salario:.2f}')
# Out:
# Salário: R$ 350.00

# %% [markdown]
# #### 8. Vamos criar um conversor de temperatura. Faça um Programa que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius.
# $C = \frac{5}{9}(F-32)$

# %%
far = int(input("Digite os graus em Fahrenheit: "))

celcius = 5 / 9 * (far - 32)

print(f'Graus Celcius {celcius}°')
# Out:
# Graus Celcius 23.88888888888889°

# %% [markdown]
# #### 9. Faça um Programa que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
# $F = \frac{9}{5}C + 32$

# %%
celcius = int(input('Digite os graus em Célcius: '))

far =  9 / 5 * celcius + 32

print(f'Graus Fahrenheit: {far}°')
# Out:
# Graus Fahrenheit: 86.0°

# %% [markdown]
# #### 10. Tendo como dados de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, usando a seguinte fórmula:
# $P = 72,7h - 58$
#
# Lembrando que "algoritmo" nada mais é do que um programa, como todos os outros que você vem fazendo

# %%
altura = float(input('Digite sua altura com casas decimais: '))

peso_ideal = 72.7 * altura - 58

print(f'Peso ideal para sua altura: {peso_ideal:.2f}')
# Out:
# Peso ideal para sua altura: 56.14

# %% [markdown]
# #### 11. Tendo como dado de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, utilizando as seguintes fórmulas:
# ##### a. Para homens: $P = 72,7h - 58$
# ##### b. Para mulheres: $P = 62,1h - 44,7$

# %%
peso_homens = 72.7 * altura - 58
peso_mulher = 62.1 * altura - 44.7


print('Peso idela por sexo')
print(f'Homens: {peso_homens:.2f}')
print(f'Mulheres: {peso_mulher:.2f}')
# Out:
# Peso idela por sexo
# Homens: 56.14
# Mulheres: 52.80

# %% [markdown]
# #### 12. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês.

# %%
valor_hora = float(input('Qual valor por hora? '))
horas_mes = int(input('Quantas horas trabalhadas por mês? '))

# %% [markdown]
# #####  Calcule o salário bruto (horas * salario por hora)

# %%
salario_bruto = valor_hora * horas_mes
print(f'Salario Bruto: R$ {salario_bruto:.2f}')
# Out:
# Salario Bruto: R$ 8800.00

# %% [markdown]
# ##### Calcule o desconto do IR (11% do salário bruto)

# %%
imposto_ir = salario_bruto * 0.11

print(f'Imposto IR: R$ {imposto_ir:.2f}')
# Out:
# Imposto IR: R$ 968.00

# %% [markdown]
# ##### Calcule o desconto do INSS (8% do salário bruto)

# %%
inss = salario_bruto * 0.08

print(f'INSS: R$ {inss:.2f}')
# Out:
# INSS: R$ 704.00

# %% [markdown]
# ##### Calcule o desconto do sindicato (5% do salário bruto)

# %%
sindicato = salario_bruto * 0.05

print(f'Contribuição sindical: R$ {sindicato:.2f}')
# Out:
# Contribuição sindical: R$ 440.00

# %% [markdown]
# ##### Calcule o salário líquido (salário bruto - descontos)

# %%
descontos_totais = imposto_ir + inss + sindicato
salario_liquido = salario_bruto - descontos_totais

print(f'Salário Liquido: R$ {salario_liquido:.2f}')
print(f'Total de Descontos: R$ {descontos_totais:.2f}')
# Out:
# Salário Liquido: R$ 6688.00
# Total de Descontos: R$ 2112.00

# %% [markdown]
# #### 13. Faça um programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 3 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R\$ 80,00. Informe ao usuário a quantidades de latas de tinta a serem compradas e o preço total. (para simplificação nesse momento, não se preocupe em arredondar a quantidade de latas a serem compradas - vamos trabalhar isso em breve)

# %%
metros = int(input('Quantos metros quadrados será pintado? '))

litros_tinta = metros / 3

latas = litros_tinta / 18

preco = latas * 80
print(f'Quantidade de latas: {latas:.2f}\nPreço total: R$ {preco:.2f}')
# Out:
# Quantidade de latas: 5.56
# Preço total: R$ 444.44

# %% [markdown]
# #### 14. Faça um programa que peça o tamanho de um arquivo para download (em MB) e a velocidade de um link de Internet (em Mbps), calcule e informe o tempo aproximado de download do arquivo usando este link (em minutos).
#
# Detalhe: MB significa megabyte, Mb (com b minúsculo) significa megabit. Um megabit é 1/8 de um megabyte.

# %%
arquivo = float(input('Informe o tamanho do arquivo em MB: '))
velocidade = float(input('Informe a velocidade da conexão em Mbps: '))

tamanho_megabits = arquivo * 8

tempo = tamanho_megabits / velocidade

tempo_minutos = tempo / 60
print(f'O tempo de download é de {tempo_minutos:.2f} minutos')
# Out:
# O tempo de download é de 0.17 minutos
